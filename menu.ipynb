# %%
import pandas as pd
menu_df = pd.read_csv('metadata.csv')
menu_df.head()
# Out:
#           PPN      Title                                           Subtitle  \
# 0  177826588X  Menükarte                     Lunch, "S.S. Kaiser Wilhelm I"
# 1  1778979165  Menükarte                              Menü, Hotel Kaiserhof
# 2  1779373368  Menükarte             Speisekarte, Die Möwe, Haus der Künste
# 3  177937335X  Menükarte                        Menü, Hotel Bayerischer Hof
# 4  1778976050  Weinkarte  Weinprobe gegeben aus Anlaß des Kontinentalen ...
#
#    Language                                     Extent  \
# 0  ger, eng  1 Blatt Druck (mehrfarbig) 19,0 x 13,0 cm
# 1       ger               1 Blatt Druck 22,5 x 15,0 cm
# 2       ger               1 Blatt Druck 21,0 x 15,0 cm
# 3       ger               1 Blatt Druck 19,0 x 10,5 cm
# 4       ger               1 Blatt Druck 21,0 x 15,0 cm
#
#                                          Description  \
# 0  Vorderseite: Oben Meeresszenerie mit großen Da...
# 1  Klappkarte, Vorderseite: ….; Innenseite: Einle...
# 2  nur Vorderseite:….;Speise- und Getränkeangebot...
# 3             nur Vorderseite:…; Menü und Tageskarte
# 4  Klappkarte; Vorderseite:…; Innenseite: Probenf...
#
#                                                Place  Date  \
# 0  Australienfahrt der "Kaiser Wilhelm II" Nordde...  2018
# 1                                             Berlin  1961
# 2                                             Berlin  1947
# 3                                            München  1946
# 4                                             Berlin  1936
#
#                                                  URL  \
# 0  https://resolver.staatsbibliothek-berlin.de/SB...
# 1  https://resolver.staatsbibliothek-berlin.de/SB...
# 2  https://resolver.staatsbibliothek-berlin.de/SB...
# 3  https://resolver.staatsbibliothek-berlin.de/SB...
# 4  https://resolver.staatsbibliothek-berlin.de/SB...
#
#                Location_Original PPN_Original                 License  \
# 0  SBB-PK Berlin Menuekarte 159b   1778261035  Public Domain Mark 1.0
# 1  SBB-PK Berlin Menuekarte 2556   1778912346  Public Domain Mark 1.0
# 2  SBB-PK Berlin Menuekarte 1631   1779372310  Public Domain Mark 1.0
# 3  SBB-PK Berlin Menuekarte 1464   1779372302  Public Domain Mark 1.0
# 4  SBB-PK Berlin Menuekarte 1466   1778908756  Public Domain Mark 1.0
#
#                                    IIIF_Manifest_URL
# 0  https://content.staatsbibliothek-berlin.de/dc/...
# 1  https://content.staatsbibliothek-berlin.de/dc/...
# 2  https://content.staatsbibliothek-berlin.de/dc/...
# 3  https://content.staatsbibliothek-berlin.de/dc/...
# 4  https://content.staatsbibliothek-berlin.de/dc/...

# %%
menu_df.isnull().sum()
# Out:
# PPN                   0
# Title                 0
# Subtitle             90
# Language              0
# Extent                0
# Description           0
# Place                 0
# Date                  0
# URL                   0
# Location_Original     0
# PPN_Original          0
# License               0
# IIIF_Manifest_URL     0
# dtype: int64

# %%
# Drop rows with missing values
menu_df_cleaned = menu_df.dropna()
menu_df_cleaned.info()
menu_df_cleaned.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2313 entries, 0 to 2402
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PPN                2313 non-null   object
#  1   Title              2313 non-null   object
#  2   Subtitle           2313 non-null   object
#  3   Language           2313 non-null   object
#  4   Extent             2313 non-null   object
#  5   Description        2313 non-null   object
#  6   Place              2313 non-null   object
#  7   Date               2313 non-null   int64
#  8   URL                2313 non-null   object
#  9   Location_Original  2313 non-null   object
#  10  PPN_Original       2313 non-null   object
#  11  License            2313 non-null   object
#  12  IIIF_Manifest_URL  2313 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 253.0+ KB
# PPN                  0
# Title                0
# Subtitle             0
# Language             0
# Extent               0
# Description          0
# Place                0
# Date                 0
# URL                  0
# Location_Original    0
# PPN_Original         0
# License              0
# IIIF_Manifest_URL    0
# dtype: int64

# %%
music_df = pd.read_csv('metadata_music.csv')
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PPN                          110 non-null    object
#  1   Title                        110 non-null    object
#  2   Subtitle                     79 non-null     object
#  3   Creator                      58 non-null     object
#  4   AdditionalCreators           99 non-null     object
#  5   AdditionalCorporateCreators  49 non-null     object
#  6   Language                     110 non-null    object
#  7   PhysicalDescription          110 non-null    object
#  8   Place                        110 non-null    object
#  9   Date                         110 non-null    object
#  10  Publisher                    108 non-null    object
#  11  Notes                        98 non-null     object
#  12  Shelfmark_Original           110 non-null    object
#  13  PPN_Original                 110 non-null    object
#  14  License                      110 non-null    object
# dtypes: object(15)
# memory usage: 13.0+ KB

# %%
music_df.isnull().sum()
# Out:
# PPN                             0
# Title                           0
# Subtitle                       31
# Creator                        52
# AdditionalCreators             11
# AdditionalCorporateCreators    61
# Language                        0
# PhysicalDescription             0
# Place                           0
# Date                            0
# Publisher                       2
# Notes                          12
# Shelfmark_Original              0
# PPN_Original                    0
# License                         0
# dtype: int64

# %%
# Drop rows with missing values
music_df_cleaned = music_df.dropna()
music_df_cleaned.info()
music_df_cleaned.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 80
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PPN                          11 non-null     object
#  1   Title                        11 non-null     object
#  2   Subtitle                     11 non-null     object
#  3   Creator                      11 non-null     object
#  4   AdditionalCreators           11 non-null     object
#  5   AdditionalCorporateCreators  11 non-null     object
#  6   Language                     11 non-null     object
#  7   PhysicalDescription          11 non-null     object
#  8   Place                        11 non-null     object
#  9   Date                         11 non-null     object
#  10  Publisher                    11 non-null     object
#  11  Notes                        11 non-null     object
#  12  Shelfmark_Original           11 non-null     object
#  13  PPN_Original                 11 non-null     object
#  14  License                      11 non-null     object
# dtypes: object(15)
# memory usage: 1.4+ KB
# PPN                            0
# Title                          0
# Subtitle                       0
# Creator                        0
# AdditionalCreators             0
# AdditionalCorporateCreators    0
# Language                       0
# PhysicalDescription            0
# Place                          0
# Date                           0
# Publisher                      0
# Notes                          0
# Shelfmark_Original             0
# PPN_Original                   0
# License                        0
# dtype: int64

# %%
#Heatmap to visualize missing values
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))         
sns.heatmap(music_df.isnull(), cbar=False, cmap='viridis')  
plt.title('Missing Values Heatmap')
plt.show()

# %%
music_df_cleaned['Year'] = pd.to_datetime(music_df_cleaned['Date'], errors='coerce').dt.year
# Out:
# /var/folders/tj/8m4f2hl545d85f9bhjg24z500000gn/T/ipykernel_28174/3730494011.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   music_df_cleaned['Year'] = pd.to_datetime(music_df_cleaned['Date'], errors='coerce').dt.year
# /var/folders/tj/8m4f2hl545d85f9bhjg24z500000gn/T/ipykernel_28174/3730494011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   music_df_cleaned['Year'] = pd.to_datetime(music_df_cleaned['Date'], errors='coerce').dt.year

# %%
import pandas as pd
import numpy as np

# Copy to avoid altering original
df_num = music_df_cleaned.copy()

# 1. Extract numeric year from Date column
df_num['Year'] = pd.to_datetime(df_num['Date'], errors='coerce').dt.year

# 2. Text length features
df_num['Title_Length'] = df_num['Title'].astype(str).str.len()
df_num['Subtitle_Length'] = df_num['Subtitle'].astype(str).str.len()
df_num['Creator_Count'] = df_num['Creator'].astype(str).apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
df_num['AdditionalCreators_Count'] = df_num['AdditionalCreators'].astype(str).apply(lambda x: len(x.split(',')) if isinstance(x, str) else 0)
df_num['Notes_Length'] = df_num['Notes'].astype(str).str.len()
df_num['PhysicalDescription_Length'] = df_num['PhysicalDescription'].astype(str).str.len()
df_num['Publisher_Length'] = df_num['Publisher'].astype(str).str.len()
df_num['Place_Length'] = df_num['Place'].astype(str).str.len()
# Out:
# /var/folders/tj/8m4f2hl545d85f9bhjg24z500000gn/T/ipykernel_28174/2980212243.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_num['Year'] = pd.to_datetime(df_num['Date'], errors='coerce').dt.year

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation on numeric columns
corr_matrix = df_num.corr(numeric_only=True)

plt.figure(figsize=(10, 8))

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    fmt=".2f"
)

plt.title('Music Metadata Correlation Heatmap', fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_features = [
    'Year',
    'Title_Length',
    'Subtitle_Length',
    'Notes_Length',
    'Creator_Count',
    'AdditionalCreators_Count'
]

# Use only rows with valid Language values
df_lang = df_num.dropna(subset=['Language'])

sns.pairplot(
    df_lang[selected_features + ['Language']], 
    hue='Language', 
    diag_kind='kde',
    corner=True,
    palette='tab10',
    plot_kws={'alpha': 0.6, 's': 40}
)

plt.suptitle("Music Metadata Relationships by Language", y=1.02, fontsize=16)
plt.show()

# %%
menu_df_cleaned.head()
# Out:
#           PPN      Title                                           Subtitle  \
# 0  177826588X  Menükarte                     Lunch, "S.S. Kaiser Wilhelm I"
# 1  1778979165  Menükarte                              Menü, Hotel Kaiserhof
# 2  1779373368  Menükarte             Speisekarte, Die Möwe, Haus der Künste
# 3  177937335X  Menükarte                        Menü, Hotel Bayerischer Hof
# 4  1778976050  Weinkarte  Weinprobe gegeben aus Anlaß des Kontinentalen ...
#
#    Language                                     Extent  \
# 0  ger, eng  1 Blatt Druck (mehrfarbig) 19,0 x 13,0 cm
# 1       ger               1 Blatt Druck 22,5 x 15,0 cm
# 2       ger               1 Blatt Druck 21,0 x 15,0 cm
# 3       ger               1 Blatt Druck 19,0 x 10,5 cm
# 4       ger               1 Blatt Druck 21,0 x 15,0 cm
#
#                                          Description  \
# 0  Vorderseite: Oben Meeresszenerie mit großen Da...
# 1  Klappkarte, Vorderseite: ….; Innenseite: Einle...
# 2  nur Vorderseite:….;Speise- und Getränkeangebot...
# 3             nur Vorderseite:…; Menü und Tageskarte
# 4  Klappkarte; Vorderseite:…; Innenseite: Probenf...
#
#                                                Place  Date  \
# 0  Australienfahrt der "Kaiser Wilhelm II" Nordde...  2018
# 1                                             Berlin  1961
# 2                                             Berlin  1947
# 3                                            München  1946
# 4                                             Berlin  1936
#
#                                                  URL  \
# 0  https://resolver.staatsbibliothek-berlin.de/SB...
# 1  https://resolver.staatsbibliothek-berlin.de/SB...
# 2  https://resolver.staatsbibliothek-berlin.de/SB...
# 3  https://resolver.staatsbibliothek-berlin.de/SB...
# 4  https://resolver.staatsbibliothek-berlin.de/SB...
#
#                Location_Original PPN_Original                 License  \
# 0  SBB-PK Berlin Menuekarte 159b   1778261035  Public Domain Mark 1.0
# 1  SBB-PK Berlin Menuekarte 2556   1778912346  Public Domain Mark 1.0
# 2  SBB-PK Berlin Menuekarte 1631   1779372310  Public Domain Mark 1.0
# 3  SBB-PK Berlin Menuekarte 1464   1779372302  Public Domain Mark 1.0
# 4  SBB-PK Berlin Menuekarte 1466   1778908756  Public Domain Mark 1.0
#
#                                    IIIF_Manifest_URL
# 0  https://content.staatsbibliothek-berlin.de/dc/...
# 1  https://content.staatsbibliothek-berlin.de/dc/...
# 2  https://content.staatsbibliothek-berlin.de/dc/...
# 3  https://content.staatsbibliothek-berlin.de/dc/...
# 4  https://content.staatsbibliothek-berlin.de/dc/...

# %% [markdown]
# ### Clean & Prepare Both Datasets

# %%
import pandas as pd

# Copy to avoid altering originals
music = music_df_cleaned.copy()
menu = menu_df_cleaned.copy()

# Add a label for dataset source
music["Collection"] = "Music"
menu["Collection"] = "Menu"

# Convert Date → Year
for df in [music, menu]:
    df["Year"] = pd.to_datetime(df["Date"], errors="coerce").dt.year

# Combine both datasets
combined = pd.concat([music, menu], ignore_index=True)

# Map language codes to readable names
lang_map = {
    "ger": "German",
    "zxx": "Instrumental / No Language",
    "fre": "French",
    "ita": "Italian",
    "eng": "English"
}
combined["Language_Name"] = combined["Language"].map(lang_map).fillna(combined["Language"])
# Out:
# /var/folders/tj/8m4f2hl545d85f9bhjg24z500000gn/T/ipykernel_28174/969330718.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Year"] = pd.to_datetime(df["Date"], errors="coerce").dt.year

# %% [markdown]
# ### Basic Exploratory Analysis

# %% [markdown]
# Record Counts

# %%
combined["Collection"].value_counts()
# Out:
# Collection
# Menu     2313
# Music      11
# Name: count, dtype: int64

# %% [markdown]
# Year Range

# %%
combined["Year"].describe()
# Out:
# count    2313.0
# mean     1970.0
# std         0.0
# min      1970.0
# 25%      1970.0
# 50%      1970.0
# 75%      1970.0
# max      1970.0
# Name: Year, dtype: float64

# %% [markdown]
# Language Distribution

# %%
combined["Language_Name"].value_counts()
# Out:
# Language_Name
# German                        1164
# French                         851
# ger, eng                       130
# fre, ger                        77
# English                         62
# eng, fre                        11
# Instrumental / No Language       5
# und                              5
# ger, fre                         5
# Italian                          4
# ger, fre, eng                    2
# ger, hun                         2
# fre, ita                         2
# fre, chi                         2
# eng, ger                         1
# lat                              1
# Name: count, dtype: int64

# %% [markdown]
# ### Visualizations

# %% [markdown]
# Number of Works Over Time

# %% [markdown]
# Language Distribution by Collection

# %%
sns.countplot(data=combined, y="Language_Name", hue="Collection")
plt.title("Language Distribution in Music vs Menu Data")
plt.show()

# %% [markdown]
# Top Places

# %%
sns.countplot(
    data=combined,
    y="Place",
    hue="Collection",
    order=combined["Place"].value_counts().head(10).index
)
plt.title("Top 10 Places by Collection")
plt.show()

# %%
#pip install wordcloud

# %% [markdown]
# ### World Cloud

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all titles into a single text string
text = " ".join(combined["Title"].dropna().astype(str))

# Generate the word cloud
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis',   # Optional: gives a nicer color tone
    max_words=200,        # Limit to most frequent words
    stopwords={'und', 'the', 'and', 'of', 'in', 'de', 'der', 'ein'}  # Add common stopwords to ignore
).generate(text)

# Plot it
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Most Common Words in Titles (Menu + Music Data)")
plt.show()

# %%
menu_df_cleaned.head(20)
# Out:
#            PPN        Title  \
# 0   177826588X    Menükarte
# 1   1778979165    Menükarte
# 2   1779373368    Menükarte
# 3   177937335X    Menükarte
# 4   1778976050    Weinkarte
# 5   1779373597  Speisekarte
# 6   1779373589  Speisekarte
# 7   1778980678    Frühstück
# 8   1779373600    Menükarte
# 9   1778980260    Menükarte
# 10  1778980252    Menükarte
# 11  1778980244    Menükarte
# 12  1778980236    Menükarte
# 13  1778980228    Menükarte
# 14  177898021X    Menükarte
# 15  1778980201    Menükarte
# 16  1778980198    Menükarte
# 17  177898018X    Menükarte
# 18  1778980171    Menükarte
# 19  1778980163    Menükarte
#
#                                              Subtitle  Language  \
# 0                      Lunch, "S.S. Kaiser Wilhelm I"  ger, eng
# 1                               Menü, Hotel Kaiserhof       ger
# 2              Speisekarte, Die Möwe, Haus der Künste       ger
# 3                         Menü, Hotel Bayerischer Hof       ger
# 4   Weinprobe gegeben aus Anlaß des Kontinentalen ...       ger
# 5            Kriegs-Speisen-Karte, Hauptbahnhof Halle       ger
# 6                                Weinhaus "Rheingold"       ger
# 7   Besuch Österreichischer u. UngarischerPresseve...       ger
# 8                                                Menü       ger
# 9                                               Diner       fre
# 10                                               Menü       fre
# 11                                               Menü       fre
# 12                                               Menü       fre
# 13                                               Menü       fre
# 14                                               Menü       fre
# 15                                               Menü       ger
# 16                                               Menü       ger
# 17                                               Menü       ger
# 18                                               Menü       ger
# 19                              Königliche Abendtafel       ger
#
#                                        Extent  \
# 0   1 Blatt Druck (mehrfarbig) 19,0 x 13,0 cm
# 1                1 Blatt Druck 22,5 x 15,0 cm
# 2                1 Blatt Druck 21,0 x 15,0 cm
# 3                1 Blatt Druck 19,0 x 10,5 cm
# 4                1 Blatt Druck 21,0 x 15,0 cm
# 5                1 Blatt Druck 35,0 x 15,5 cm
# 6                1 Blatt Druck 37,0 x 25,0 cm
# 7               1 Blatt Druck 21,0 x 122,5 cm
# 8                 1 Blatt Druck 18,0 x 8,0 cm
# 9                1 Blatt Druck 20,0 x 12,5 cm
# 10               1 Blatt Druck 20,0 x 12,5 cm
# 11                1 Blatt Druck 14,5 x 9,5 cm
# 12                1 Blatt Druck 14,5 x 9,5 cm
# 13                1 Blatt Druck 14,5 x 9,5 cm
# 14                1 Blatt Druck 14,5 x 9,5 cm
# 15               1 Blatt Druck 16,0 x 10,5 cm
# 16               1 Blatt Druck 16,0 x 10,5 cm
# 17               1 Blatt Druck 16,0 x 10,5 cm
# 18               1 Blatt Druck 16,0 x 10,5 cm
# 19               1 Blatt Druck 17,0 x 10,5 cm
#
#                                           Description  \
# 0   Vorderseite: Oben Meeresszenerie mit großen Da...
# 1   Klappkarte, Vorderseite: ….; Innenseite: Einle...
# 2   nur Vorderseite:….;Speise- und Getränkeangebot...
# 3              nur Vorderseite:…; Menü und Tageskarte
# 4   Klappkarte; Vorderseite:…; Innenseite: Probenf...
# 5                nur Vorderseite: ….; Speisenangebote
# 6   Vorderseite: Abb. d. Weinhauses Rheingold, Mit...
# 7   ^nur Vorderseite: Berliner Bär; Speisenfolge u...
# 8   nur Vorderseite: Abb. der Iisis, Speisenfolge;...
# 9         nur Vs:…;, handschr. Anmerkung: Fürst Solms
# 10        nur Vs:…;, handschr. Anmerkung: Fürst Solms
# 11                    nur Vorderseite:…; Speisenfolge
# 12                    nur Vorderseite:…; Speisenfolge
# 13                    nur Vorderseite:…; Speisenfolge
# 14                    nur Vorderseite:…; Speisenfolge
# 15                    nur Vorderseite:…; Speisenfolge
# 16                    nur Vorderseite:…; Speisenfolge
# 17                    nur Vorderseite:…; Speisenfolge
# 18                    nur Vorderseite:…; Speisenfolge
# 19  nur Vorderseite: Kartusche mit 2 Wappen, Krone...
#
#                                                 Place  Date  \
# 0   Australienfahrt der "Kaiser Wilhelm II" Nordde...  2018
# 1                                              Berlin  1961
# 2                                              Berlin  1947
# 3                                             München  1946
# 4                                              Berlin  1936
# 5                                               Halle  1917
# 6                                              Berlin  1917
# 7                                              Berlin  1917
# 8                                       [Deutschland]  1916
# 9                                       [Deutschland]  1914
# 10                                      [Deutschland]  1914
# 11                                      [Deutschland]  1914
# 12                                      [Deutschland]  1914
# 13                                      [Deutschland]  1914
# 14                                      [Deutschland]  1914
# 15                                      [Deutschland]  1914
# 16                                      [Deutschland]  1914
# 17                                      [Deutschland]  1914
# 18                                      [Deutschland]  1914
# 19                                             Berlin  1914
#
#                                                   URL  \
# 0   https://resolver.staatsbibliothek-berlin.de/SB...
# 1   https://resolver.staatsbibliothek-berlin.de/SB...
# 2   https://resolver.staatsbibliothek-berlin.de/SB...
# 3   https://resolver.staatsbibliothek-berlin.de/SB...
# 4   https://resolver.staatsbibliothek-berlin.de/SB...
# 5   https://resolver.staatsbibliothek-berlin.de/SB...
# 6   https://resolver.staatsbibliothek-berlin.de/SB...
# 7   https://resolver.staatsbibliothek-berlin.de/SB...
# 8   https://resolver.staatsbibliothek-berlin.de/SB...
# 9   https://resolver.staatsbibliothek-berlin.de/SB...
# 10  https://resolver.staatsbibliothek-berlin.de/SB...
# 11  https://resolver.staatsbibliothek-berlin.de/SB...
# 12  https://resolver.staatsbibliothek-berlin.de/SB...
# 13  https://resolver.staatsbibliothek-berlin.de/SB...
# 14  https://resolver.staatsbibliothek-berlin.de/SB...
# 15  https://resolver.staatsbibliothek-berlin.de/SB...
# 16  https://resolver.staatsbibliothek-berlin.de/SB...
# 17  https://resolver.staatsbibliothek-berlin.de/SB...
# 18  https://resolver.staatsbibliothek-berlin.de/SB...
# 19  https://resolver.staatsbibliothek-berlin.de/SB...
#
#                   Location_Original PPN_Original                 License  \
# 0     SBB-PK Berlin Menuekarte 159b   1778261035  Public Domain Mark 1.0
# 1     SBB-PK Berlin Menuekarte 2556   1778912346  Public Domain Mark 1.0
# 2     SBB-PK Berlin Menuekarte 1631   1779372310  Public Domain Mark 1.0
# 3     SBB-PK Berlin Menuekarte 1464   1779372302  Public Domain Mark 1.0
# 4     SBB-PK Berlin Menuekarte 1466   1778908756  Public Domain Mark 1.0
# 5     SBB-PK Berlin Menuekarte 2844   1779372523  Public Domain Mark 1.0
# 6     SBB-PK Berlin Menuekarte 2843   1779372515  Public Domain Mark 1.0
# 7   SBB-PK Berlin Menuekarte 2842,1   1778914128  Public Domain Mark 1.0
# 8     SBB-PK Berlin Menuekarte 2846   1779372558  Public Domain Mark 1.0
# 9     SBB-PK Berlin Menuekarte 2750   1778913601  Public Domain Mark 1.0
# 10    SBB-PK Berlin Menuekarte 2749   1778913598  Public Domain Mark 1.0
# 11    SBB-PK Berlin Menuekarte 2739   177891358X  Public Domain Mark 1.0
# 12    SBB-PK Berlin Menuekarte 2738   1778913563  Public Domain Mark 1.0
# 13    SBB-PK Berlin Menuekarte 2737   1778913555  Public Domain Mark 1.0
# 14    SBB-PK Berlin Menuekarte 2736   1778913547  Public Domain Mark 1.0
# 15    SBB-PK Berlin Menuekarte 2732   1778913520  Public Domain Mark 1.0
# 16   SBB-PK Berlin Menuekarte 2731a   1778913512  Public Domain Mark 1.0
# 17    SBB-PK Berlin Menuekarte 2731   1778913504  Public Domain Mark 1.0
# 18    SBB-PK Berlin Menuekarte 2730   1778913490  Public Domain Mark 1.0
# 19    SBB-PK Berlin Menuekarte 2729   1778913482  Public Domain Mark 1.0
#
#                                     IIIF_Manifest_URL
# 0   https://content.staatsbibliothek-berlin.de/dc/...
# 1   https://content.staatsbibliothek-berlin.de/dc/...
# 2   https://content.staatsbibliothek-berlin.de/dc/...
# 3   https://content.staatsbibliothek-berlin.de/dc/...
# 4   https://content.staatsbibliothek-berlin.de/dc/...
# 5   https://content.staatsbibliothek-berlin.de/dc/...
# 6   https://content.staatsbibliothek-berlin.de/dc/...
# 7   https://content.staatsbibliothek-berlin.de/dc/...
# 8   https://content.staatsbibliothek-berlin.de/dc/...
# 9   https://content.staatsbibliothek-berlin.de/dc/...
# 10  https://content.staatsbibliothek-berlin.de/dc/...
# 11  https://content.staatsbibliothek-berlin.de/dc/...
# 12  https://content.staatsbibliothek-berlin.de/dc/...
# 13  https://content.staatsbibliothek-berlin.de/dc/...
# 14  https://content.staatsbibliothek-berlin.de/dc/...
# 15  https://content.staatsbibliothek-berlin.de/dc/...
# 16  https://content.staatsbibliothek-berlin.de/dc/...
# 17  https://content.staatsbibliothek-berlin.de/dc/...
# 18  https://content.staatsbibliothek-berlin.de/dc/...
# 19  https://content.staatsbibliothek-berlin.de/dc/...

# %% [markdown]
# ### Read another CSV with date till 1915

# %%
music_df_1915 = pd.read_csv('metadata_pre_1915.csv')

music_df_1915.head(30)
# Out:
#            PPN                                          Title  \
# 0   1858515122             Glühwürmchen-Idyll aus "Lysistrata
# 1   1915787300                         Immer an der Wand lang
# 2   1870762614                           Der letzte Frou-Frou
# 3   1870761863                       Der zurückgekehrte Taler
# 4   1870746953                                      Donaunixe
# 5   1869141725                           Der letzte Frou Frou
# 6   1869140095                                    Börsenduett
# 7   1869139445                              Der Gardeleutnant
# 8   1869130650                                Schutzmann-Lied
# 9   1916013554             Komm hilf mir mal die Rolle drehn!
# 10  1870694287                                           Cora
# 11  1870694074                               Satyr und Nymphe
# 12  1870692918                                   Walzer-Duett
# 13  1870692586                                    Allerseelen
# 14  1915481643                      Er ist nach mir verrückt!
# 15  1915476321   Nach meine Beene is ja janz Berlin verrückt!
# 16  1915484529                         Das Lied von der Mühle
# 17  1915478944  Hab'n wir uns nicht schon mal kenn'n gelernt?
# 18  1870691903                                   Vive l'amour
# 19  187074635X                                    La gran via
# 20  1916011772                         Immer an der Wand lang
# 21  1915785243                                    Ach, Amalia
# 22  1915493382                        Der Herr von Methusalem
# 23  1915478553           Kleine Mädchen müssen schlafen geh'n
# 24  191490110X                   Mein geliebtes Firlefänzchen
# 25  1914588142                                  Haiti-Ballade
# 26  1914898214  Haben wir uns nicht schon mal kenn'n gelernt?
# 27  1870746651                                    Fascination
# 28  1870694783                                    Fascination
# 29  1870612663                                   Vive l'amour
#
#                                              Subtitle  \
# 0                                                 NaN
# 1                                         Rheinländer
# 2                                                 NaN
# 3                                                 NaN
# 4           Rheinländer [aus "Donnerwetter tadellos"]
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                   1. Teil : German comic with orch.
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  I. [und] II. Teil : aus "Hallo! Die große Revu...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                   aus "Filmzauber"
# 17                       Walzerduett aus "Filmzauber"
# 18   Wenn im Lenz die Knospen sprießen : aus "Grigri"
# 19                                             Walzer
# 20                                        Rheinländer
# 21                              aus "Die Kinokönigin"
# 22                             aus "Wie einst im Mai"
# 23                Duett aus der Posse: "Der Juxbaron"
# 24                             aus "Wie einst im Mai"
# 25          Two-Step aus der Posse "Wie einst im Mai"
# 26  Walzer-Duett aus der Posse "Filmzauber" : Repe...
# 27                                             Walzer
# 28                                                NaN
# 29                  Wenn im Lenz die Knospen sprießen
#
#                                               Creator  \
# 0   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 1                                                 NaN
# 2   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 3   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 4                                                 NaN
# 5   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 6   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 7   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 8   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 9                                                 NaN
# 10  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 11  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 12  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 13                                                NaN
# 14                                                NaN
# 15  Kollo, Walter (KomponistIn), https://d-nb.info...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Kollo, Walter (KomponistIn), https://d-nb.info...
# 24                                                NaN
# 25  Kollo, Walter (KomponistIn), https://d-nb.info...
# 26  Kollo, Walter (KomponistIn), https://d-nb.info...
# 27                                                NaN
# 28                                                NaN
# 29  Lincke, Paul (KomponistIn), https://d-nb.info/...
#
#                                    AdditionalCreators  \
# 0                                                 NaN
# 1   ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 2   ['Wehlen, Emmy (SängerIn), https://d-nb.info/g...
# 3   ['Kettner, Martin (SängerIn), https://d-nb.inf...
# 4   ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 5   ['Freund, Julius (LibrettistIn), https://d-nb....
# 6   ['Wiedecke, Grete (SängerIn), https://d-nb.inf...
# 7   ['Kettner, Martin (SängerIn), https://d-nb.inf...
# 8   ['Bender, Henry (AusführendeR), https://d-nb.i...
# 9   ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 10  ['Lessing, Madge (SängerIn), https://d-nb.info...
# 11  ['Freund, Julius (TextdichterIn), https://d-nb...
# 12  ['Freund, Julius (TextdichterIn), https://d-nb...
# 13  ['Lassen, Eduard (KomponistIn), https://d-nb.i...
# 14  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 15  ['Hardt, Ernst (TextdichterIn), https://d-nb.i...
# 16  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 17  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 18  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 19  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 20  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 21  ['Gilbert, Jean (KomponistIn), https://d-nb.in...
# 22  ['Bredschneider, Willy (KomponistIn), https://...
# 23  ['Werkmeister, Lotte (SängerIn), https://d-nb....
# 24  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 25  ['Dora, Josefine (SängerIn), https://d-nb.info...
# 26  ['Nitter, Erna (SängerIn), https://d-nb.info/g...
# 27  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 28  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 29  ['Wiedecke, Grete (SängerIn), https://d-nb.inf...
#
#                           AdditionalCorporateCreators Language  \
# 0   ['Berliner Elite-Orchester (AusführendeR), htt...      zxx
# 1                                                 NaN      ger
# 2                                                 NaN      ger
# 3                                                 NaN      ger
# 4   ['Seidler-Orchester (InstrumentalmusikerIn), h...      zxx
# 5                                                 NaN      ger
# 6                                                 NaN      ger
# 7                                                 NaN      ger
# 8                                                 NaN      ger
# 9                                                 NaN      ger
# 10                                                NaN      ger
# 11                                                NaN      ger
# 12                                                NaN      ger
# 13                                                NaN      ger
# 14                                                NaN      ger
# 15                                                NaN      ger
# 16                                                NaN      ger
# 17                                                NaN      ger
# 18                                                NaN      ger
# 19  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 20                                                NaN      zxx
# 21                                                NaN      ger
# 22                                                NaN      ger
# 23                                                NaN      ger
# 24                                                NaN      ger
# 25                                                NaN      ger
# 26  ['Dacapo-Orchester (InstrumentalmusikerIn), ht...      ger
# 27                                                NaN      zxx
# 28                                                NaN      zxx
# 29                                                NaN      ger
#
#              PhysicalDescription                                Place  \
# 0    1 Schellackplatte (1 Seite)                     [United Kingdom]
# 1   1 Schellackplatte (2 Seiten)                             [Berlin]
# 2   1 Schellackplatte (2 Seiten)  [Erscheinungsort nicht ermittelbar]
# 3   1 Schellackplatte (2 Seiten)                             [Berlin]
# 4   1 Schellackplatte (2 Seiten)                             [Berlin]
# 5   1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 6   1 Schellackplatte (2 Seiten)                              Einbeck
# 7   1 Schellackplatte (2 Seiten)                               Berlin
# 8   1 Schellackplatte (2 Seiten)                             [Berlin]
# 9   1 Schellackplatte (2 Seiten)                             [Paris?]
# 10  1 Schellackplatte (2 Seiten)                             [Berlin]
# 11  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 12  1 Schellackplatte (2 Seiten)                             [London]
# 13  1 Schellackplatte (2 Seiten)                             [Berlin]
# 14  1 Schellackplatte (2 Seiten)                             [Berlin]
# 15  1 Schellackplatte (2 Seiten)                             [Berlin]
# 16  1 Schellackplatte (2 Seiten)                               [S.l.]
# 17  1 Schellackplatte (2 Seiten)                               [S.l.]
# 18  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 19  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 20  1 Schellackplatte (2 Seiten)                               [S.l.]
# 21  1 Schellackplatte (2 Seiten)                            [Leipzig]
# 22  1 Schellackplatte (2 Seiten)                               [S.l.]
# 23  1 Schellackplatte (2 Seiten)                    [Hannover-Linden]
# 24  1 Schellackplatte (2 Seiten)                               [S.l.]
# 25  1 Schellackplatte (2 Seiten)  [Erscheinungsort nicht ermittelbar]
# 26  1 Schellackplatte (2 Seiten)                             [Berlin]
# 27  1 Schellackplatte (2 Seiten)                             [Berlin]
# 28  1 Schellackplatte (2 Seiten)                             [Berlin]
# 29  1 Schellackplatte (2 Seiten)                               Berlin
#
#                         Date  \
# 0                    [1902?]
# 1                       1908
# 2                    [1908?]
# 3                    [1908?]
# 4                    [1908?]
# 5                    [1908?]
# 6                     [1908]
# 7                    [1908?]
# 8                    [1908?]
# 9                 [ca. 1909]
# 10                   [1909?]
# 11                   [1909?]
# 12                   [1909?]
# 13                   [1910?]
# 14                [ca. 1911]
# 15                    [1911]
# 16                    [1912]
# 17                   [1912?]
# 18                   [1912?]
# 19  [zwischen 1908 und 1912]
# 20  [zwischen 1909 und 1912]
# 21                    [1913]
# 22                    [1913]
# 23                    [1913]
# 24                   [1913?]
# 25                    [1913]
# 26          [1912 oder 1913]
# 27               [nach 1908]
# 28               [nach 1908]
# 29                [um 1914?]
#
#                                             Publisher  \
# 0   The Gramophone and Typewriter Ltd., and Sister...
# 1                                            Homokord
# 2                                           Zonophone
# 3        The Gramophone Company, and Sister Companies
# 4    Gramophone Company Limited, and Sister Companies
# 5        The Gramophone Company, and Sister Companies
# 6                                  August Stukenbrock
# 7                                           Zonophone
# 8                            Gramophon Concert Record
# 9                                              Ultima
# 10                                         Grammophon
# 11             Gramophone Co. (and Sister Ciompanies)
# 12     The Gramophone Co. Ltd. (and Sister Companies)
# 13                                         Gramophone
# 14                                         Grammophon
# 15                                         Grammophon
# 16                                         Gramophone
# 17                                         Gramophone
# 18                                  Zonophone Records
# 19                                       Jumbo Record
# 20                                       Jumbo-Record
# 21                                 Famosa Glockophona
# 22                                         Gramophone
# 23                                    Favorite Record
# 24                                         Gramophone
# 25                                   Parlophon-Record
# 26                              Dacapo-Record Company
# 27                                  Zonophone Records
# 28                                  Zonophone Records
# 29             Deutsche Grammophon-Aktiengesellschaft
#
#                                                 Notes Shelfmark_Original  \
# 0                                  German | Orchestra           SPL 6718
# 1                  Orchester und Orchester mit Gesang           SPL 7491
# 2   Soprano w. orchestra | Erscheinungsdatum gesch...           SPL 6738
# 3   Comic with orch | Erscheinungsdatum anhand des...           SPL 3971
# 4   German | Orchestra | Erscheinungsdatum anhand ...           SPL 6748
# 5   Soprano w. orch | Tenor w. orch | Erscheinungs...           SPL 3431
# 6                         Erscheinungsdatum geschätzt           SPL 4533
# 7   German comic with orch | Erscheinungsdatum ges...           SPL 9934
# 8   Erscheinungsdatum anhand des Aufnahmedatums ge...           SPL 4542
# 9   Mit eingraviertem Etikett; Tiefenschrift; spie...           SPL 9965
# 10  Duet w. orch. (Cora) | Soprano w. orch. (Pst, ...           SPL 3608
# 11  Duet with orchestra | Erscheinungsdatum anhand...           SPL 9880
# 12                                       Duet w. orch           SPL 3645
# 13  Verlag: Hainauer (Allerseelen), Apollo-Verlag ...           SPL 8587
# 14  Komik m. Piano | Die Aufnahmen basieren auf de...           SPL 3892
# 15  Komik mit Piano | Hergestellt von der Deutsche...           SPL 3628
# 16  Tenor w. Orch | Manufactured by Deutsche Gramm...           SPL 3934
# 17  Basiert auf der Notenausgabe vom Drei Masken-V...           SPL 3786
# 18  Die Aufnahmen basieren auf den Notenausgaben v...           SPL 8739
# 19  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 20                                                NaN           SPL 9093
# 21  Orchester mit Gesang; Orchester | Erscheinungs...           SPL 5379
# 22  Die Aufnahme basiert auf der Notenausgabe vom ...           SPL 4543
# 23                                 Duo with Orchestra           SPL 3774
# 24  Terzett mit Orchester. Tenor mit Orchester | D...           SPL 3577
# 25                                                NaN            SPL 633
# 26  Gesungen von Erna Nitter-Götz und Karl Platen,...           SPL 3472
# 27  German | Orchestra | Datierung nach Lotz u. a....           SPL 8515
# 28   German | Orchestra | Erscheinungsdatum geschätzt          SPL 11794
# 29  Duet w. orch | Bass w. choir and orch | (Apoll...           SPL 3625
#
#    PPN_Original
# 0    1815185880
# 1    1839396253
# 2    1810667585
# 3    1810668522
# 4    1811011020
# 5    1810596432
# 6    1810591570
# 7    1807551024
# 8    1804462942
# 9    1844921700
# 10   181143004X
# 11   1811430627
# 12   1811904378
# 13   1815646756
# 14   1837011540
# 15   1836529279
# 16   1837975523
# 17   183654314X
# 18   1811337961
# 19   1815650796
# 20   1843070561
# 21   1838498354
# 22   1838152601
# 23   1836532032
# 24   1834153220
# 25   1833761162
# 26   1834131812
# 27   1815187727
# 28   1859282768
# 29   181133007X

# %%
import pandas as pd
import re

# Assume your dataframe is called df (either menu_df_cleaned or music_df_cleaned)
df = music_df_1915.copy()

def expand_year_ranges(row):
    """
    For a given row, if Date contains a range like '1915-1918',
    it will return a list of years [1915, 1916, 1917, 1918].
    Otherwise, returns the single year.
    """
    text = str(row["Date"])
    years = re.findall(r"(1[0-9]{3}|20[0-9]{2})", text)

    if len(years) == 2:
        start, end = map(int, years)
        return list(range(start, end + 1))
    elif len(years) == 1:
        return [int(years[0])]
    else:
        return [None]  # If no valid year found

# Apply expansion logic
expanded_rows = []

for _, row in df.iterrows():
    for year in expand_year_ranges(row):
        new_row = row.copy()
        new_row["Year"] = year
        expanded_rows.append(new_row)

# Create new expanded DataFrame
expanded_df = pd.DataFrame(expanded_rows)

# Optional: drop rows without valid year
expanded_df = expanded_df.dropna(subset=["Year"]).reset_index(drop=True)

#print(expanded_df[["Date", "Year"]].head(15))
expanded_df.head()
expanded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PPN                          54 non-null     object
#  1   Title                        54 non-null     object
#  2   Subtitle                     34 non-null     object
#  3   Creator                      22 non-null     object
#  4   AdditionalCreators           50 non-null     object
#  5   AdditionalCorporateCreators  12 non-null     object
#  6   Language                     54 non-null     object
#  7   PhysicalDescription          54 non-null     object
#  8   Place                        54 non-null     object
#  9   Date                         54 non-null     object
#  10  Publisher                    54 non-null     object
#  11  Notes                        49 non-null     object
#  12  Shelfmark_Original           54 non-null     object
#  13  PPN_Original                 54 non-null     object
#  14  Year                         54 non-null     int64
# dtypes: int64(1), object(14)
# memory usage: 6.5+ KB

# %%
expanded_df
# Out:
#            PPN                                          Title  \
# 0   1858515122             Glühwürmchen-Idyll aus "Lysistrata
# 1   1915787300                         Immer an der Wand lang
# 2   1870762614                           Der letzte Frou-Frou
# 3   1870761863                       Der zurückgekehrte Taler
# 4   1870746953                                      Donaunixe
# 5   1869141725                           Der letzte Frou Frou
# 6   1869140095                                    Börsenduett
# 7   1869139445                              Der Gardeleutnant
# 8   1869130650                                Schutzmann-Lied
# 9   1916013554             Komm hilf mir mal die Rolle drehn!
# 10  1870694287                                           Cora
# 11  1870694074                               Satyr und Nymphe
# 12  1870692918                                   Walzer-Duett
# 13  1870692586                                    Allerseelen
# 14  1915481643                      Er ist nach mir verrückt!
# 15  1915476321   Nach meine Beene is ja janz Berlin verrückt!
# 16  1915484529                         Das Lied von der Mühle
# 17  1915478944  Hab'n wir uns nicht schon mal kenn'n gelernt?
# 18  1870691903                                   Vive l'amour
# 19  187074635X                                    La gran via
# 20  187074635X                                    La gran via
# 21  187074635X                                    La gran via
# 22  187074635X                                    La gran via
# 23  187074635X                                    La gran via
# 24  1916011772                         Immer an der Wand lang
# 25  1916011772                         Immer an der Wand lang
# 26  1916011772                         Immer an der Wand lang
# 27  1916011772                         Immer an der Wand lang
# 28  1915785243                                    Ach, Amalia
# 29  1915493382                        Der Herr von Methusalem
# 30  1915478553           Kleine Mädchen müssen schlafen geh'n
# 31  191490110X                   Mein geliebtes Firlefänzchen
# 32  1914588142                                  Haiti-Ballade
# 33  1914898214  Haben wir uns nicht schon mal kenn'n gelernt?
# 34  1914898214  Haben wir uns nicht schon mal kenn'n gelernt?
# 35  1870746651                                    Fascination
# 36  1870694783                                    Fascination
# 37  1870612663                                   Vive l'amour
# 38  1870612396                          Von der Heimat weitab
# 39  1870691172                                    Am Bosporus
# 40  1870691172                                    Am Bosporus
# 41  1870691172                                    Am Bosporus
# 42  1870689097                              Die grosse Kanone
# 43  1870689097                              Die grosse Kanone
# 44  1870689097                              Die grosse Kanone
# 45  1916013899                         Bubi, mein süßer Bubi!
# 46  1916013899                         Bubi, mein süßer Bubi!
# 47  1870694589                                        Märchen
# 48  1870694589                                        Märchen
# 49  1870694589                                        Märchen
# 50  1870694589                                        Märchen
# 51  1870694589                                        Märchen
# 52  1870694589                                        Märchen
# 53  1870694589                                        Märchen
#
#                                              Subtitle  \
# 0                                                 NaN
# 1                                         Rheinländer
# 2                                                 NaN
# 3                                                 NaN
# 4           Rheinländer [aus "Donnerwetter tadellos"]
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                   1. Teil : German comic with orch.
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  I. [und] II. Teil : aus "Hallo! Die große Revu...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                   aus "Filmzauber"
# 17                       Walzerduett aus "Filmzauber"
# 18   Wenn im Lenz die Knospen sprießen : aus "Grigri"
# 19                                             Walzer
# 20                                             Walzer
# 21                                             Walzer
# 22                                             Walzer
# 23                                             Walzer
# 24                                        Rheinländer
# 25                                        Rheinländer
# 26                                        Rheinländer
# 27                                        Rheinländer
# 28                              aus "Die Kinokönigin"
# 29                             aus "Wie einst im Mai"
# 30                Duett aus der Posse: "Der Juxbaron"
# 31                             aus "Wie einst im Mai"
# 32          Two-Step aus der Posse "Wie einst im Mai"
# 33  Walzer-Duett aus der Posse "Filmzauber" : Repe...
# 34  Walzer-Duett aus der Posse "Filmzauber" : Repe...
# 35                                             Walzer
# 36                                                NaN
# 37                  Wenn im Lenz die Knospen sprießen
# 38        Finale II. Akt (Grigri-Walzer) aus "Grigri"
# 39                      aus "Halloh! Die große Revue"
# 40                      aus "Halloh! Die große Revue"
# 41                      aus "Halloh! Die große Revue"
# 42                                  I. [und] II. Teil
# 43                                  I. [und] II. Teil
# 44                                  I. [und] II. Teil
# 45                            Lied aus "Der Juxbaron"
# 46                            Lied aus "Der Juxbaron"
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
#
#                                               Creator  \
# 0   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 1                                                 NaN
# 2   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 3   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 4                                                 NaN
# 5   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 6   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 7   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 8   Lincke, Paul (KomponistIn), https://d-nb.info/...
# 9                                                 NaN
# 10  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 11  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 12  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 13                                                NaN
# 14                                                NaN
# 15  Kollo, Walter (KomponistIn), https://d-nb.info...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  Kollo, Walter (KomponistIn), https://d-nb.info...
# 31                                                NaN
# 32  Kollo, Walter (KomponistIn), https://d-nb.info...
# 33  Kollo, Walter (KomponistIn), https://d-nb.info...
# 34  Kollo, Walter (KomponistIn), https://d-nb.info...
# 35                                                NaN
# 36                                                NaN
# 37  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 38  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 43  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 44  Lincke, Paul (KomponistIn), https://d-nb.info/...
# 45  Kollo, Walter (KomponistIn), https://d-nb.info...
# 46  Kollo, Walter (KomponistIn), https://d-nb.info...
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
#
#                                    AdditionalCreators  \
# 0                                                 NaN
# 1   ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 2   ['Wehlen, Emmy (SängerIn), https://d-nb.info/g...
# 3   ['Kettner, Martin (SängerIn), https://d-nb.inf...
# 4   ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 5   ['Freund, Julius (LibrettistIn), https://d-nb....
# 6   ['Wiedecke, Grete (SängerIn), https://d-nb.inf...
# 7   ['Kettner, Martin (SängerIn), https://d-nb.inf...
# 8   ['Bender, Henry (AusführendeR), https://d-nb.i...
# 9   ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 10  ['Lessing, Madge (SängerIn), https://d-nb.info...
# 11  ['Freund, Julius (TextdichterIn), https://d-nb...
# 12  ['Freund, Julius (TextdichterIn), https://d-nb...
# 13  ['Lassen, Eduard (KomponistIn), https://d-nb.i...
# 14  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 15  ['Hardt, Ernst (TextdichterIn), https://d-nb.i...
# 16  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 17  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 18  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 19  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 20  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 21  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 22  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 23  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 24  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 25  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 26  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 27  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 28  ['Gilbert, Jean (KomponistIn), https://d-nb.in...
# 29  ['Bredschneider, Willy (KomponistIn), https://...
# 30  ['Werkmeister, Lotte (SängerIn), https://d-nb....
# 31  ['Kollo, Walter (KomponistIn), https://d-nb.in...
# 32  ['Dora, Josefine (SängerIn), https://d-nb.info...
# 33  ['Nitter, Erna (SängerIn), https://d-nb.info/g...
# 34  ['Nitter, Erna (SängerIn), https://d-nb.info/g...
# 35  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 36  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 37  ['Wiedecke, Grete (SängerIn), https://d-nb.inf...
# 38  ['Bolten-Baeckers, Heinrich (TextdichterIn), h...
# 39  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 40  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 41  ['Lincke, Paul (KomponistIn), https://d-nb.inf...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  ['Wolff, Willi (LibrettistIn), https://d-nb.in...
# 46  ['Wolff, Willi (LibrettistIn), https://d-nb.in...
# 47  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 48  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 49  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 50  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 51  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 52  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
# 53  ['Aletter, Wilhelm (KomponistIn), https://d-nb...
#
#                           AdditionalCorporateCreators Language  \
# 0   ['Berliner Elite-Orchester (AusführendeR), htt...      zxx
# 1                                                 NaN      ger
# 2                                                 NaN      ger
# 3                                                 NaN      ger
# 4   ['Seidler-Orchester (InstrumentalmusikerIn), h...      zxx
# 5                                                 NaN      ger
# 6                                                 NaN      ger
# 7                                                 NaN      ger
# 8                                                 NaN      ger
# 9                                                 NaN      ger
# 10                                                NaN      ger
# 11                                                NaN      ger
# 12                                                NaN      ger
# 13                                                NaN      ger
# 14                                                NaN      ger
# 15                                                NaN      ger
# 16                                                NaN      ger
# 17                                                NaN      ger
# 18                                                NaN      ger
# 19  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 20  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 21  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 22  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 23  ['Grosses Dannenberg-Orchester (Instrumentalmu...      zxx
# 24                                                NaN      zxx
# 25                                                NaN      zxx
# 26                                                NaN      zxx
# 27                                                NaN      zxx
# 28                                                NaN      ger
# 29                                                NaN      ger
# 30                                                NaN      ger
# 31                                                NaN      ger
# 32                                                NaN      ger
# 33  ['Dacapo-Orchester (InstrumentalmusikerIn), ht...      ger
# 34  ['Dacapo-Orchester (InstrumentalmusikerIn), ht...      ger
# 35                                                NaN      zxx
# 36                                                NaN      zxx
# 37                                                NaN      ger
# 38                                                NaN      ger
# 39                                                NaN      zxx
# 40                                                NaN      zxx
# 41                                                NaN      zxx
# 42  ['Stettiner Sänger (SängerIn), https://d-nb.in...      ger
# 43  ['Stettiner Sänger (SängerIn), https://d-nb.in...      ger
# 44  ['Stettiner Sänger (SängerIn), https://d-nb.in...      ger
# 45                                                NaN      ger
# 46                                                NaN      ger
# 47                                                NaN      zxx
# 48                                                NaN      zxx
# 49                                                NaN      zxx
# 50                                                NaN      zxx
# 51                                                NaN      zxx
# 52                                                NaN      zxx
# 53                                                NaN      zxx
#
#              PhysicalDescription                                Place  \
# 0    1 Schellackplatte (1 Seite)                     [United Kingdom]
# 1   1 Schellackplatte (2 Seiten)                             [Berlin]
# 2   1 Schellackplatte (2 Seiten)  [Erscheinungsort nicht ermittelbar]
# 3   1 Schellackplatte (2 Seiten)                             [Berlin]
# 4   1 Schellackplatte (2 Seiten)                             [Berlin]
# 5   1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 6   1 Schellackplatte (2 Seiten)                              Einbeck
# 7   1 Schellackplatte (2 Seiten)                               Berlin
# 8   1 Schellackplatte (2 Seiten)                             [Berlin]
# 9   1 Schellackplatte (2 Seiten)                             [Paris?]
# 10  1 Schellackplatte (2 Seiten)                             [Berlin]
# 11  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 12  1 Schellackplatte (2 Seiten)                             [London]
# 13  1 Schellackplatte (2 Seiten)                             [Berlin]
# 14  1 Schellackplatte (2 Seiten)                             [Berlin]
# 15  1 Schellackplatte (2 Seiten)                             [Berlin]
# 16  1 Schellackplatte (2 Seiten)                               [S.l.]
# 17  1 Schellackplatte (2 Seiten)                               [S.l.]
# 18  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 19  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 20  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 21  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 22  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 23  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 24  1 Schellackplatte (2 Seiten)                               [S.l.]
# 25  1 Schellackplatte (2 Seiten)                               [S.l.]
# 26  1 Schellackplatte (2 Seiten)                               [S.l.]
# 27  1 Schellackplatte (2 Seiten)                               [S.l.]
# 28  1 Schellackplatte (2 Seiten)                            [Leipzig]
# 29  1 Schellackplatte (2 Seiten)                               [S.l.]
# 30  1 Schellackplatte (2 Seiten)                    [Hannover-Linden]
# 31  1 Schellackplatte (2 Seiten)                               [S.l.]
# 32  1 Schellackplatte (2 Seiten)  [Erscheinungsort nicht ermittelbar]
# 33  1 Schellackplatte (2 Seiten)                             [Berlin]
# 34  1 Schellackplatte (2 Seiten)                             [Berlin]
# 35  1 Schellackplatte (2 Seiten)                             [Berlin]
# 36  1 Schellackplatte (2 Seiten)                             [Berlin]
# 37  1 Schellackplatte (2 Seiten)                               Berlin
# 38  1 Schellackplatte (2 Seiten)                             [Berlin]
# 39  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 40  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 41  1 Schellackplatte (2 Seiten)       [Verlagsort nicht ermittelbar]
# 42  1 Schellackplatte (2 Seiten)                             [Berlin]
# 43  1 Schellackplatte (2 Seiten)                             [Berlin]
# 44  1 Schellackplatte (2 Seiten)                             [Berlin]
# 45  1 Schellackplatte (2 Seiten)                               [S.l.]
# 46  1 Schellackplatte (2 Seiten)                               [S.l.]
# 47  1 Schellackplatte (2 Seiten)                               Berlin
# 48  1 Schellackplatte (2 Seiten)                               Berlin
# 49  1 Schellackplatte (2 Seiten)                               Berlin
# 50  1 Schellackplatte (2 Seiten)                               Berlin
# 51  1 Schellackplatte (2 Seiten)                               Berlin
# 52  1 Schellackplatte (2 Seiten)                               Berlin
# 53  1 Schellackplatte (2 Seiten)                               Berlin
#
#                         Date  \
# 0                    [1902?]
# 1                       1908
# 2                    [1908?]
# 3                    [1908?]
# 4                    [1908?]
# 5                    [1908?]
# 6                     [1908]
# 7                    [1908?]
# 8                    [1908?]
# 9                 [ca. 1909]
# 10                   [1909?]
# 11                   [1909?]
# 12                   [1909?]
# 13                   [1910?]
# 14                [ca. 1911]
# 15                    [1911]
# 16                    [1912]
# 17                   [1912?]
# 18                   [1912?]
# 19  [zwischen 1908 und 1912]
# 20  [zwischen 1908 und 1912]
# 21  [zwischen 1908 und 1912]
# 22  [zwischen 1908 und 1912]
# 23  [zwischen 1908 und 1912]
# 24  [zwischen 1909 und 1912]
# 25  [zwischen 1909 und 1912]
# 26  [zwischen 1909 und 1912]
# 27  [zwischen 1909 und 1912]
# 28                    [1913]
# 29                    [1913]
# 30                    [1913]
# 31                   [1913?]
# 32                    [1913]
# 33          [1912 oder 1913]
# 34          [1912 oder 1913]
# 35               [nach 1908]
# 36               [nach 1908]
# 37                [um 1914?]
# 38                [um 1914?]
# 39  [zwischen 1912 und 1914]
# 40  [zwischen 1912 und 1914]
# 41  [zwischen 1912 und 1914]
# 42  [zwischen 1912 und 1914]
# 43  [zwischen 1912 und 1914]
# 44  [zwischen 1912 und 1914]
# 45          [1913 oder 1914]
# 46          [1913 oder 1914]
# 47  [zwischen 1908 und 1914]
# 48  [zwischen 1908 und 1914]
# 49  [zwischen 1908 und 1914]
# 50  [zwischen 1908 und 1914]
# 51  [zwischen 1908 und 1914]
# 52  [zwischen 1908 und 1914]
# 53  [zwischen 1908 und 1914]
#
#                                             Publisher  \
# 0   The Gramophone and Typewriter Ltd., and Sister...
# 1                                            Homokord
# 2                                           Zonophone
# 3        The Gramophone Company, and Sister Companies
# 4    Gramophone Company Limited, and Sister Companies
# 5        The Gramophone Company, and Sister Companies
# 6                                  August Stukenbrock
# 7                                           Zonophone
# 8                            Gramophon Concert Record
# 9                                              Ultima
# 10                                         Grammophon
# 11             Gramophone Co. (and Sister Ciompanies)
# 12     The Gramophone Co. Ltd. (and Sister Companies)
# 13                                         Gramophone
# 14                                         Grammophon
# 15                                         Grammophon
# 16                                         Gramophone
# 17                                         Gramophone
# 18                                  Zonophone Records
# 19                                       Jumbo Record
# 20                                       Jumbo Record
# 21                                       Jumbo Record
# 22                                       Jumbo Record
# 23                                       Jumbo Record
# 24                                       Jumbo-Record
# 25                                       Jumbo-Record
# 26                                       Jumbo-Record
# 27                                       Jumbo-Record
# 28                                 Famosa Glockophona
# 29                                         Gramophone
# 30                                    Favorite Record
# 31                                         Gramophone
# 32                                   Parlophon-Record
# 33                              Dacapo-Record Company
# 34                              Dacapo-Record Company
# 35                                  Zonophone Records
# 36                                  Zonophone Records
# 37             Deutsche Grammophon-Aktiengesellschaft
# 38             Deutsche Grammophon Aktiengesellschaft
# 39                         [Verlag nicht ermittelbar]
# 40                         [Verlag nicht ermittelbar]
# 41                         [Verlag nicht ermittelbar]
# 42                                       Kunst-Record
# 43                                       Kunst-Record
# 44                                       Kunst-Record
# 45                                         Gramophone
# 46                                         Gramophone
# 47             Deutsche Grammophon-Aktiengesellschaft
# 48             Deutsche Grammophon-Aktiengesellschaft
# 49             Deutsche Grammophon-Aktiengesellschaft
# 50             Deutsche Grammophon-Aktiengesellschaft
# 51             Deutsche Grammophon-Aktiengesellschaft
# 52             Deutsche Grammophon-Aktiengesellschaft
# 53             Deutsche Grammophon-Aktiengesellschaft
#
#                                                 Notes Shelfmark_Original  \
# 0                                  German | Orchestra           SPL 6718
# 1                  Orchester und Orchester mit Gesang           SPL 7491
# 2   Soprano w. orchestra | Erscheinungsdatum gesch...           SPL 6738
# 3   Comic with orch | Erscheinungsdatum anhand des...           SPL 3971
# 4   German | Orchestra | Erscheinungsdatum anhand ...           SPL 6748
# 5   Soprano w. orch | Tenor w. orch | Erscheinungs...           SPL 3431
# 6                         Erscheinungsdatum geschätzt           SPL 4533
# 7   German comic with orch | Erscheinungsdatum ges...           SPL 9934
# 8   Erscheinungsdatum anhand des Aufnahmedatums ge...           SPL 4542
# 9   Mit eingraviertem Etikett; Tiefenschrift; spie...           SPL 9965
# 10  Duet w. orch. (Cora) | Soprano w. orch. (Pst, ...           SPL 3608
# 11  Duet with orchestra | Erscheinungsdatum anhand...           SPL 9880
# 12                                       Duet w. orch           SPL 3645
# 13  Verlag: Hainauer (Allerseelen), Apollo-Verlag ...           SPL 8587
# 14  Komik m. Piano | Die Aufnahmen basieren auf de...           SPL 3892
# 15  Komik mit Piano | Hergestellt von der Deutsche...           SPL 3628
# 16  Tenor w. Orch | Manufactured by Deutsche Gramm...           SPL 3934
# 17  Basiert auf der Notenausgabe vom Drei Masken-V...           SPL 3786
# 18  Die Aufnahmen basieren auf den Notenausgaben v...           SPL 8739
# 19  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 20  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 21  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 22  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 23  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 6746
# 24                                                NaN           SPL 9093
# 25                                                NaN           SPL 9093
# 26                                                NaN           SPL 9093
# 27                                                NaN           SPL 9093
# 28  Orchester mit Gesang; Orchester | Erscheinungs...           SPL 5379
# 29  Die Aufnahme basiert auf der Notenausgabe vom ...           SPL 4543
# 30                                 Duo with Orchestra           SPL 3774
# 31  Terzett mit Orchester. Tenor mit Orchester | D...           SPL 3577
# 32                                                NaN            SPL 633
# 33  Gesungen von Erna Nitter-Götz und Karl Platen,...           SPL 3472
# 34  Gesungen von Erna Nitter-Götz und Karl Platen,...           SPL 3472
# 35  German | Orchestra | Datierung nach Lotz u. a....           SPL 8515
# 36   German | Orchestra | Erscheinungsdatum geschätzt          SPL 11794
# 37  Duet w. orch | Bass w. choir and orch | (Apoll...           SPL 3625
# 38  Apollo-Verlag | Duet w. orch | soprano w. orch...           SPL 4530
# 39  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 9911
# 40  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 9911
# 41  Erscheinungsdatum nicht ermittelbar. Dieses La...           SPL 9911
# 42  Erscheinungsdatum geschätzt nach Lotz, R. u.a....           SPL 9061
# 43  Erscheinungsdatum geschätzt nach Lotz, R. u.a....           SPL 9061
# 44  Erscheinungsdatum geschätzt nach Lotz, R. u.a....           SPL 9061
# 45  Hergestellt von der Deutschen Grammophon-Aktie...           SPL 9999
# 46  Hergestellt von der Deutschen Grammophon-Aktie...           SPL 9999
# 47  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 48  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 49  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 50  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 51  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 52  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
# 53  instrumental duet | Erscheinungsdatum ermittel...           SPL 8724
#
#    PPN_Original  Year
# 0    1815185880  1902
# 1    1839396253  1908
# 2    1810667585  1908
# 3    1810668522  1908
# 4    1811011020  1908
# 5    1810596432  1908
# 6    1810591570  1908
# 7    1807551024  1908
# 8    1804462942  1908
# 9    1844921700  1909
# 10   181143004X  1909
# 11   1811430627  1909
# 12   1811904378  1909
# 13   1815646756  1910
# 14   1837011540  1911
# 15   1836529279  1911
# 16   1837975523  1912
# 17   183654314X  1912
# 18   1811337961  1912
# 19   1815650796  1908
# 20   1815650796  1909
# 21   1815650796  1910
# 22   1815650796  1911
# 23   1815650796  1912
# 24   1843070561  1909
# 25   1843070561  1910
# 26   1843070561  1911
# 27   1843070561  1912
# 28   1838498354  1913
# 29   1838152601  1913
# 30   1836532032  1913
# 31   1834153220  1913
# 32   1833761162  1913
# 33   1834131812  1912
# 34   1834131812  1913
# 35   1815187727  1908
# 36   1859282768  1908
# 37   181133007X  1914
# 38   1811331068  1914
# 39   1811339689  1912
# 40   1811339689  1913
# 41   1811339689  1914
# 42   1869120752  1912
# 43   1869120752  1913
# 44   1869120752  1914
# 45   1847354513  1913
# 46   1847354513  1914
# 47   1868941663  1908
# 48   1868941663  1909
# 49   1868941663  1910
# 50   1868941663  1911
# 51   1868941663  1912
# 52   1868941663  1913
# 53   1868941663  1914

# %% [markdown]
# ### Renaming the values

# %%
import pandas as pd

# List of columns to clean (update with your actual text columns)
columns_to_clean = ['Place','Publisher','AdditionalCorporateCreators','PPN','Title','Subtitle','Creator','AdditionalCreators','Language','Notes','PhysicalDescription','Date','Shelfmark_Original','PPN_Original','Year']

def clean_text_column(series):
    """
    Cleans a text column by:
    - Removing square brackets []
    - Removing quotes '
    - Stripping extra whitespace
    """
    return (
        series.astype(str)        # Ensure string type
              .str.strip()        # Remove leading/trailing spaces
              .str.strip('[]')    # Remove square brackets
              .str.strip('"\'')   # Remove quotes
    )

# Apply cleaning to all listed columns
for col in columns_to_clean:
    if col in expanded_df.columns:
        expanded_df[col] = clean_text_column(expanded_df[col])

# Optional: Standardize capitalization
expanded_df[columns_to_clean] = expanded_df[columns_to_clean].apply(lambda x: x.str.title())
expanded_df.head(50)
# Out:
#            PPN                                          Title  \
# 0   1858515122             Glühwürmchen-Idyll Aus "Lysistrata
# 1   1915787300                         Immer An Der Wand Lang
# 2   1870762614                           Der Letzte Frou-Frou
# 3   1870761863                       Der Zurückgekehrte Taler
# 4   1870746953                                      Donaunixe
# 5   1869141725                           Der Letzte Frou Frou
# 6   1869140095                                    Börsenduett
# 7   1869139445                              Der Gardeleutnant
# 8   1869130650                                Schutzmann-Lied
# 9   1916013554             Komm Hilf Mir Mal Die Rolle Drehn!
# 10  1870694287                                           Cora
# 11  1870694074                               Satyr Und Nymphe
# 12  1870692918                                   Walzer-Duett
# 13  1870692586                                    Allerseelen
# 14  1915481643                      Er Ist Nach Mir Verrückt!
# 15  1915476321   Nach Meine Beene Is Ja Janz Berlin Verrückt!
# 16  1915484529                         Das Lied Von Der Mühle
# 17  1915478944  Hab'N Wir Uns Nicht Schon Mal Kenn'N Gelernt?
# 18  1870691903                                   Vive L'Amour
# 19  187074635X                                    La Gran Via
# 20  187074635X                                    La Gran Via
# 21  187074635X                                    La Gran Via
# 22  187074635X                                    La Gran Via
# 23  187074635X                                    La Gran Via
# 24  1916011772                         Immer An Der Wand Lang
# 25  1916011772                         Immer An Der Wand Lang
# 26  1916011772                         Immer An Der Wand Lang
# 27  1916011772                         Immer An Der Wand Lang
# 28  1915785243                                    Ach, Amalia
# 29  1915493382                        Der Herr Von Methusalem
# 30  1915478553           Kleine Mädchen Müssen Schlafen Geh'N
# 31  191490110X                   Mein Geliebtes Firlefänzchen
# 32  1914588142                                  Haiti-Ballade
# 33  1914898214  Haben Wir Uns Nicht Schon Mal Kenn'N Gelernt?
# 34  1914898214  Haben Wir Uns Nicht Schon Mal Kenn'N Gelernt?
# 35  1870746651                                    Fascination
# 36  1870694783                                    Fascination
# 37  1870612663                                   Vive L'Amour
# 38  1870612396                          Von Der Heimat Weitab
# 39  1870691172                                    Am Bosporus
# 40  1870691172                                    Am Bosporus
# 41  1870691172                                    Am Bosporus
# 42  1870689097                              Die Grosse Kanone
# 43  1870689097                              Die Grosse Kanone
# 44  1870689097                              Die Grosse Kanone
# 45  1916013899                         Bubi, Mein Süßer Bubi!
# 46  1916013899                         Bubi, Mein Süßer Bubi!
# 47  1870694589                                        Märchen
# 48  1870694589                                        Märchen
# 49  1870694589                                        Märchen
#
#                                              Subtitle  \
# 0                                                 Nan
# 1                                         Rheinländer
# 2                                                 Nan
# 3                                                 Nan
# 4             Rheinländer [Aus "Donnerwetter Tadellos
# 5                                                 Nan
# 6                                                 Nan
# 7                                                 Nan
# 8                   1. Teil : German Comic With Orch.
# 9                                                 Nan
# 10                                                Nan
# 11                                                Nan
# 12  I. [Und] Ii. Teil : Aus "Hallo! Die Große Revu...
# 13                                                Nan
# 14                                                Nan
# 15                                                Nan
# 16                                    Aus "Filmzauber
# 17                        Walzerduett Aus "Filmzauber
# 18    Wenn Im Lenz Die Knospen Sprießen : Aus "Grigri
# 19                                             Walzer
# 20                                             Walzer
# 21                                             Walzer
# 22                                             Walzer
# 23                                             Walzer
# 24                                        Rheinländer
# 25                                        Rheinländer
# 26                                        Rheinländer
# 27                                        Rheinländer
# 28                               Aus "Die Kinokönigin
# 29                              Aus "Wie Einst Im Mai
# 30                 Duett Aus Der Posse: "Der Juxbaron
# 31                              Aus "Wie Einst Im Mai
# 32           Two-Step Aus Der Posse "Wie Einst Im Mai
# 33  Walzer-Duett Aus Der Posse "Filmzauber" : Repe...
# 34  Walzer-Duett Aus Der Posse "Filmzauber" : Repe...
# 35                                             Walzer
# 36                                                Nan
# 37                  Wenn Im Lenz Die Knospen Sprießen
# 38         Finale Ii. Akt (Grigri-Walzer) Aus "Grigri
# 39                       Aus "Halloh! Die Große Revue
# 40                       Aus "Halloh! Die Große Revue
# 41                       Aus "Halloh! Die Große Revue
# 42                                  I. [Und] Ii. Teil
# 43                                  I. [Und] Ii. Teil
# 44                                  I. [Und] Ii. Teil
# 45                             Lied Aus "Der Juxbaron
# 46                             Lied Aus "Der Juxbaron
# 47                                                Nan
# 48                                                Nan
# 49                                                Nan
#
#                                               Creator  \
# 0   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 1                                                 Nan
# 2   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 3   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 4                                                 Nan
# 5   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 6   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 7   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 8   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 9                                                 Nan
# 10  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 11  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 12  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 13                                                Nan
# 14                                                Nan
# 15  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 16                                                Nan
# 17                                                Nan
# 18                                                Nan
# 19                                                Nan
# 20                                                Nan
# 21                                                Nan
# 22                                                Nan
# 23                                                Nan
# 24                                                Nan
# 25                                                Nan
# 26                                                Nan
# 27                                                Nan
# 28                                                Nan
# 29                                                Nan
# 30  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 31                                                Nan
# 32  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 33  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 34  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 35                                                Nan
# 36                                                Nan
# 37  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 38  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 39                                                Nan
# 40                                                Nan
# 41                                                Nan
# 42  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 43  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 44  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 45  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 46  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 47                                                Nan
# 48                                                Nan
# 49                                                Nan
#
#                                    AdditionalCreators  \
# 0                                                 Nan
# 1   Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 2   Wehlen, Emmy (Sängerin), Https://D-Nb.Info/Gnd...
# 3   Kettner, Martin (Sängerin), Https://D-Nb.Info/...
# 4   Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 5   Freund, Julius (Librettistin), Https://D-Nb.In...
# 6   Wiedecke, Grete (Sängerin), Https://D-Nb.Info/...
# 7   Kettner, Martin (Sängerin), Https://D-Nb.Info/...
# 8   Bender, Henry (Ausführender), Https://D-Nb.Inf...
# 9   Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 10  Lessing, Madge (Sängerin), Https://D-Nb.Info/G...
# 11  Freund, Julius (Textdichterin), Https://D-Nb.I...
# 12  Freund, Julius (Textdichterin), Https://D-Nb.I...
# 13  Lassen, Eduard (Komponistin), Https://D-Nb.Inf...
# 14  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 15  Hardt, Ernst (Textdichterin), Https://D-Nb.Inf...
# 16  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 17  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 18  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 19  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 20  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 21  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 22  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 23  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 24  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 25  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 26  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 27  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 28  Gilbert, Jean (Komponistin), Https://D-Nb.Info...
# 29  Bredschneider, Willy (Komponistin), Https://D-...
# 30  Werkmeister, Lotte (Sängerin), Https://D-Nb.In...
# 31  Kollo, Walter (Komponistin), Https://D-Nb.Info...
# 32  Dora, Josefine (Sängerin), Https://D-Nb.Info/G...
# 33  Nitter, Erna (Sängerin), Https://D-Nb.Info/Gnd...
# 34  Nitter, Erna (Sängerin), Https://D-Nb.Info/Gnd...
# 35  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 36  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 37  Wiedecke, Grete (Sängerin), Https://D-Nb.Info/...
# 38  Bolten-Baeckers, Heinrich (Textdichterin), Htt...
# 39  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 40  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 41  Lincke, Paul (Komponistin), Https://D-Nb.Info/...
# 42                                                Nan
# 43                                                Nan
# 44                                                Nan
# 45  Wolff, Willi (Librettistin), Https://D-Nb.Info...
# 46  Wolff, Willi (Librettistin), Https://D-Nb.Info...
# 47  Aletter, Wilhelm (Komponistin), Https://D-Nb.I...
# 48  Aletter, Wilhelm (Komponistin), Https://D-Nb.I...
# 49  Aletter, Wilhelm (Komponistin), Https://D-Nb.I...
#
#                           AdditionalCorporateCreators Language  \
# 0   Berliner Elite-Orchester (Ausführender), Https...      Zxx
# 1                                                 Nan      Ger
# 2                                                 Nan      Ger
# 3                                                 Nan      Ger
# 4   Seidler-Orchester (Instrumentalmusikerin), Htt...      Zxx
# 5                                                 Nan      Ger
# 6                                                 Nan      Ger
# 7                                                 Nan      Ger
# 8                                                 Nan      Ger
# 9                                                 Nan      Ger
# 10                                                Nan      Ger
# 11                                                Nan      Ger
# 12                                                Nan      Ger
# 13                                                Nan      Ger
# 14                                                Nan      Ger
# 15                                                Nan      Ger
# 16                                                Nan      Ger
# 17                                                Nan      Ger
# 18                                                Nan      Ger
# 19  Grosses Dannenberg-Orchester (Instrumentalmusi...      Zxx
# 20  Grosses Dannenberg-Orchester (Instrumentalmusi...      Zxx
# 21  Grosses Dannenberg-Orchester (Instrumentalmusi...      Zxx
# 22  Grosses Dannenberg-Orchester (Instrumentalmusi...      Zxx
# 23  Grosses Dannenberg-Orchester (Instrumentalmusi...      Zxx
# 24                                                Nan      Zxx
# 25                                                Nan      Zxx
# 26                                                Nan      Zxx
# 27                                                Nan      Zxx
# 28                                                Nan      Ger
# 29                                                Nan      Ger
# 30                                                Nan      Ger
# 31                                                Nan      Ger
# 32                                                Nan      Ger
# 33  Dacapo-Orchester (Instrumentalmusikerin), Http...      Ger
# 34  Dacapo-Orchester (Instrumentalmusikerin), Http...      Ger
# 35                                                Nan      Zxx
# 36                                                Nan      Zxx
# 37                                                Nan      Ger
# 38                                                Nan      Ger
# 39                                                Nan      Zxx
# 40                                                Nan      Zxx
# 41                                                Nan      Zxx
# 42  Stettiner Sänger (Sängerin), Https://D-Nb.Info...      Ger
# 43  Stettiner Sänger (Sängerin), Https://D-Nb.Info...      Ger
# 44  Stettiner Sänger (Sängerin), Https://D-Nb.Info...      Ger
# 45                                                Nan      Ger
# 46                                                Nan      Ger
# 47                                                Nan      Zxx
# 48                                                Nan      Zxx
# 49                                                Nan      Zxx
#
#              PhysicalDescription                              Place  \
# 0    1 Schellackplatte (1 Seite)                     United Kingdom
# 1   1 Schellackplatte (2 Seiten)                             Berlin
# 2   1 Schellackplatte (2 Seiten)  Erscheinungsort Nicht Ermittelbar
# 3   1 Schellackplatte (2 Seiten)                             Berlin
# 4   1 Schellackplatte (2 Seiten)                             Berlin
# 5   1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 6   1 Schellackplatte (2 Seiten)                            Einbeck
# 7   1 Schellackplatte (2 Seiten)                             Berlin
# 8   1 Schellackplatte (2 Seiten)                             Berlin
# 9   1 Schellackplatte (2 Seiten)                             Paris?
# 10  1 Schellackplatte (2 Seiten)                             Berlin
# 11  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 12  1 Schellackplatte (2 Seiten)                             London
# 13  1 Schellackplatte (2 Seiten)                             Berlin
# 14  1 Schellackplatte (2 Seiten)                             Berlin
# 15  1 Schellackplatte (2 Seiten)                             Berlin
# 16  1 Schellackplatte (2 Seiten)                               S.L.
# 17  1 Schellackplatte (2 Seiten)                               S.L.
# 18  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 19  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 20  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 21  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 22  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 23  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 24  1 Schellackplatte (2 Seiten)                               S.L.
# 25  1 Schellackplatte (2 Seiten)                               S.L.
# 26  1 Schellackplatte (2 Seiten)                               S.L.
# 27  1 Schellackplatte (2 Seiten)                               S.L.
# 28  1 Schellackplatte (2 Seiten)                            Leipzig
# 29  1 Schellackplatte (2 Seiten)                               S.L.
# 30  1 Schellackplatte (2 Seiten)                    Hannover-Linden
# 31  1 Schellackplatte (2 Seiten)                               S.L.
# 32  1 Schellackplatte (2 Seiten)  Erscheinungsort Nicht Ermittelbar
# 33  1 Schellackplatte (2 Seiten)                             Berlin
# 34  1 Schellackplatte (2 Seiten)                             Berlin
# 35  1 Schellackplatte (2 Seiten)                             Berlin
# 36  1 Schellackplatte (2 Seiten)                             Berlin
# 37  1 Schellackplatte (2 Seiten)                             Berlin
# 38  1 Schellackplatte (2 Seiten)                             Berlin
# 39  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 40  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 41  1 Schellackplatte (2 Seiten)       Verlagsort Nicht Ermittelbar
# 42  1 Schellackplatte (2 Seiten)                             Berlin
# 43  1 Schellackplatte (2 Seiten)                             Berlin
# 44  1 Schellackplatte (2 Seiten)                             Berlin
# 45  1 Schellackplatte (2 Seiten)                               S.L.
# 46  1 Schellackplatte (2 Seiten)                               S.L.
# 47  1 Schellackplatte (2 Seiten)                             Berlin
# 48  1 Schellackplatte (2 Seiten)                             Berlin
# 49  1 Schellackplatte (2 Seiten)                             Berlin
#
#                       Date                                          Publisher  \
# 0                    1902?  The Gramophone And Typewriter Ltd., And Sister...
# 1                     1908                                           Homokord
# 2                    1908?                                          Zonophone
# 3                    1908?       The Gramophone Company, And Sister Companies
# 4                    1908?   Gramophone Company Limited, And Sister Companies
# 5                    1908?       The Gramophone Company, And Sister Companies
# 6                     1908                                 August Stukenbrock
# 7                    1908?                                          Zonophone
# 8                    1908?                           Gramophon Concert Record
# 9                 Ca. 1909                                             Ultima
# 10                   1909?                                         Grammophon
# 11                   1909?             Gramophone Co. (And Sister Ciompanies)
# 12                   1909?     The Gramophone Co. Ltd. (And Sister Companies)
# 13                   1910?                                         Gramophone
# 14                Ca. 1911                                         Grammophon
# 15                    1911                                         Grammophon
# 16                    1912                                         Gramophone
# 17                   1912?                                         Gramophone
# 18                   1912?                                  Zonophone Records
# 19  Zwischen 1908 Und 1912                                       Jumbo Record
# 20  Zwischen 1908 Und 1912                                       Jumbo Record
# 21  Zwischen 1908 Und 1912                                       Jumbo Record
# 22  Zwischen 1908 Und 1912                                       Jumbo Record
# 23  Zwischen 1908 Und 1912                                       Jumbo Record
# 24  Zwischen 1909 Und 1912                                       Jumbo-Record
# 25  Zwischen 1909 Und 1912                                       Jumbo-Record
# 26  Zwischen 1909 Und 1912                                       Jumbo-Record
# 27  Zwischen 1909 Und 1912                                       Jumbo-Record
# 28                    1913                                 Famosa Glockophona
# 29                    1913                                         Gramophone
# 30                    1913                                    Favorite Record
# 31                   1913?                                         Gramophone
# 32                    1913                                   Parlophon-Record
# 33          1912 Oder 1913                              Dacapo-Record Company
# 34          1912 Oder 1913                              Dacapo-Record Company
# 35               Nach 1908                                  Zonophone Records
# 36               Nach 1908                                  Zonophone Records
# 37                Um 1914?             Deutsche Grammophon-Aktiengesellschaft
# 38                Um 1914?             Deutsche Grammophon Aktiengesellschaft
# 39  Zwischen 1912 Und 1914                           Verlag Nicht Ermittelbar
# 40  Zwischen 1912 Und 1914                           Verlag Nicht Ermittelbar
# 41  Zwischen 1912 Und 1914                           Verlag Nicht Ermittelbar
# 42  Zwischen 1912 Und 1914                                       Kunst-Record
# 43  Zwischen 1912 Und 1914                                       Kunst-Record
# 44  Zwischen 1912 Und 1914                                       Kunst-Record
# 45          1913 Oder 1914                                         Gramophone
# 46          1913 Oder 1914                                         Gramophone
# 47  Zwischen 1908 Und 1914             Deutsche Grammophon-Aktiengesellschaft
# 48  Zwischen 1908 Und 1914             Deutsche Grammophon-Aktiengesellschaft
# 49  Zwischen 1908 Und 1914             Deutsche Grammophon-Aktiengesellschaft
#
#                                                 Notes Shelfmark_Original  \
# 0                                  German | Orchestra           Spl 6718
# 1                  Orchester Und Orchester Mit Gesang           Spl 7491
# 2   Soprano W. Orchestra | Erscheinungsdatum Gesch...           Spl 6738
# 3   Comic With Orch | Erscheinungsdatum Anhand Des...           Spl 3971
# 4   German | Orchestra | Erscheinungsdatum Anhand ...           Spl 6748
# 5   Soprano W. Orch | Tenor W. Orch | Erscheinungs...           Spl 3431
# 6                         Erscheinungsdatum Geschätzt           Spl 4533
# 7   German Comic With Orch | Erscheinungsdatum Ges...           Spl 9934
# 8   Erscheinungsdatum Anhand Des Aufnahmedatums Ge...           Spl 4542
# 9   Mit Eingraviertem Etikett; Tiefenschrift; Spie...           Spl 9965
# 10  Duet W. Orch. (Cora) | Soprano W. Orch. (Pst, ...           Spl 3608
# 11  Duet With Orchestra | Erscheinungsdatum Anhand...           Spl 9880
# 12                                       Duet W. Orch           Spl 3645
# 13  Verlag: Hainauer (Allerseelen), Apollo-Verlag ...           Spl 8587
# 14  Komik M. Piano | Die Aufnahmen Basieren Auf De...           Spl 3892
# 15  Komik Mit Piano | Hergestellt Von Der Deutsche...           Spl 3628
# 16  Tenor W. Orch | Manufactured By Deutsche Gramm...           Spl 3934
# 17  Basiert Auf Der Notenausgabe Vom Drei Masken-V...           Spl 3786
# 18  Die Aufnahmen Basieren Auf Den Notenausgaben V...           Spl 8739
# 19  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 6746
# 20  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 6746
# 21  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 6746
# 22  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 6746
# 23  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 6746
# 24                                                Nan           Spl 9093
# 25                                                Nan           Spl 9093
# 26                                                Nan           Spl 9093
# 27                                                Nan           Spl 9093
# 28  Orchester Mit Gesang; Orchester | Erscheinungs...           Spl 5379
# 29  Die Aufnahme Basiert Auf Der Notenausgabe Vom ...           Spl 4543
# 30                                 Duo With Orchestra           Spl 3774
# 31  Terzett Mit Orchester. Tenor Mit Orchester | D...           Spl 3577
# 32                                                Nan            Spl 633
# 33  Gesungen Von Erna Nitter-Götz Und Karl Platen,...           Spl 3472
# 34  Gesungen Von Erna Nitter-Götz Und Karl Platen,...           Spl 3472
# 35  German | Orchestra | Datierung Nach Lotz U. A....           Spl 8515
# 36   German | Orchestra | Erscheinungsdatum Geschätzt          Spl 11794
# 37  Duet W. Orch | Bass W. Choir And Orch | (Apoll...           Spl 3625
# 38  Apollo-Verlag | Duet W. Orch | Soprano W. Orch...           Spl 4530
# 39  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 9911
# 40  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 9911
# 41  Erscheinungsdatum Nicht Ermittelbar. Dieses La...           Spl 9911
# 42  Erscheinungsdatum Geschätzt Nach Lotz, R. U.A....           Spl 9061
# 43  Erscheinungsdatum Geschätzt Nach Lotz, R. U.A....           Spl 9061
# 44  Erscheinungsdatum Geschätzt Nach Lotz, R. U.A....           Spl 9061
# 45  Hergestellt Von Der Deutschen Grammophon-Aktie...           Spl 9999
# 46  Hergestellt Von Der Deutschen Grammophon-Aktie...           Spl 9999
# 47  Instrumental Duet | Erscheinungsdatum Ermittel...           Spl 8724
# 48  Instrumental Duet | Erscheinungsdatum Ermittel...           Spl 8724
# 49  Instrumental Duet | Erscheinungsdatum Ermittel...           Spl 8724
#
#    PPN_Original  Year
# 0    1815185880  1902
# 1    1839396253  1908
# 2    1810667585  1908
# 3    1810668522  1908
# 4    1811011020  1908
# 5    1810596432  1908
# 6    1810591570  1908
# 7    1807551024  1908
# 8    1804462942  1908
# 9    1844921700  1909
# 10   181143004X  1909
# 11   1811430627  1909
# 12   1811904378  1909
# 13   1815646756  1910
# 14   1837011540  1911
# 15   1836529279  1911
# 16   1837975523  1912
# 17   183654314X  1912
# 18   1811337961  1912
# 19   1815650796  1908
# 20   1815650796  1909
# 21   1815650796  1910
# 22   1815650796  1911
# 23   1815650796  1912
# 24   1843070561  1909
# 25   1843070561  1910
# 26   1843070561  1911
# 27   1843070561  1912
# 28   1838498354  1913
# 29   1838152601  1913
# 30   1836532032  1913
# 31   1834153220  1913
# 32   1833761162  1913
# 33   1834131812  1912
# 34   1834131812  1913
# 35   1815187727  1908
# 36   1859282768  1908
# 37   181133007X  1914
# 38   1811331068  1914
# 39   1811339689  1912
# 40   1811339689  1913
# 41   1811339689  1914
# 42   1869120752  1912
# 43   1869120752  1913
# 44   1869120752  1914
# 45   1847354513  1913
# 46   1847354513  1914
# 47   1868941663  1908
# 48   1868941663  1909
# 49   1868941663  1910

# %%
# Save expanded_df to CSV
expanded_df.to_csv("Music_Data_cleaned.csv", index=False)

# %%
import pandas as pd

# Add a Collection column
menu_df_cleaned['Collection'] = 'Menu'
expanded_df['Collection'] = 'Music'

# Align columns: keep only common columns or add missing ones with NaN
common_columns = list(set(menu_df_cleaned.columns).union(set(expanded_df.columns)))

menu_aligned = menu_df_cleaned.reindex(columns=common_columns)
music_aligned = expanded_df.reindex(columns=common_columns)

# Combine into one DataFrame
combined_df = pd.concat([menu_aligned, music_aligned], ignore_index=True)

# Optional: check
print(combined_df['Collection'].value_counts())
print(combined_df.head())
# Out:
# Collection
# Menu     2313
# Music      54
# Name: count, dtype: int64
#   AdditionalCorporateCreators      Title Collection         PPN  \
# 0                         NaN  Menükarte       Menu  177826588X
# 1                         NaN  Menükarte       Menu  1778979165
# 2                         NaN  Menükarte       Menu  1779373368
# 3                         NaN  Menükarte       Menu  177937335X
# 4                         NaN  Weinkarte       Menu  1778976050
#
#                   License                                  IIIF_Manifest_URL  \
# 0  Public Domain Mark 1.0  https://content.staatsbibliothek-berlin.de/dc/...
# 1  Public Domain Mark 1.0  https://content.staatsbibliothek-berlin.de/dc/...
# 2  Public Domain Mark 1.0  https://content.staatsbibliothek-berlin.de/dc/...
# 3  Public Domain Mark 1.0  https://content.staatsbibliothek-berlin.de/dc/...
# 4  Public Domain Mark 1.0  https://content.staatsbibliothek-berlin.de/dc/...
#
#    Date PPN_Original Publisher Creator  ...              Location_Original  \
# 0  2018   1778261035       NaN     NaN  ...  SBB-PK Berlin Menuekarte 159b
# 1  1961   1778912346       NaN     NaN  ...  SBB-PK Berlin Menuekarte 2556
# 2  1947   1779372310       NaN     NaN  ...  SBB-PK Berlin Menuekarte 1631
# 3  1946   1779372302       NaN     NaN  ...  SBB-PK Berlin Menuekarte 1464
# 4  1936   1778908756       NaN     NaN  ...  SBB-PK Berlin Menuekarte 1466
#
#                                             Subtitle Year AdditionalCreators  \
# 0                     Lunch, "S.S. Kaiser Wilhelm I"  NaN                NaN
# 1                              Menü, Hotel Kaiserhof  NaN                NaN
# 2             Speisekarte, Die Möwe, Haus der Künste  NaN                NaN
# 3                        Menü, Hotel Bayerischer Hof  NaN                NaN
# 4  Weinprobe gegeben aus Anlaß des Kontinentalen ...  NaN                NaN
#
#   PhysicalDescription  Language  \
# 0                 NaN  ger, eng
# 1                 NaN       ger
# 2                 NaN       ger
# 3                 NaN       ger
# 4                 NaN       ger
#
#                                                  URL Shelfmark_Original Notes  \
# 0  https://resolver.staatsbibliothek-berlin.de/SB...                NaN   NaN
# 1  https://resolver.staatsbibliothek-berlin.de/SB...                NaN   NaN
# 2  https://resolver.staatsbibliothek-berlin.de/SB...                NaN   NaN
# 3  https://resolver.staatsbibliothek-berlin.de/SB...                NaN   NaN
# 4  https://resolver.staatsbibliothek-berlin.de/SB...                NaN   NaN
#
#                                          Description
# 0  Vorderseite: Oben Meeresszenerie mit großen Da...
# 1  Klappkarte, Vorderseite: ….; Innenseite: Einle...
# 2  nur Vorderseite:….;Speise- und Getränkeangebot...
# 3             nur Vorderseite:…; Menü und Tageskarte
# 4  Klappkarte; Vorderseite:…; Innenseite: Probenf...
#
# [5 rows x 22 columns]
# /var/folders/tj/8m4f2hl545d85f9bhjg24z500000gn/T/ipykernel_28174/3021602719.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   menu_df_cleaned['Collection'] = 'Menu'

# %% [markdown]
# ### Music Vs Menu

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Ensure Year is numeric
expanded_df['Year'] = pd.to_numeric(expanded_df['Year'], errors='coerce')

# Optional: add a 'Collection' column to distinguish sources if not already present
if 'Collection' not in expanded_df.columns:
    expanded_df['Collection'] = 'Music'  # assuming expanded_df is music data

# If you also have menu_df_cleaned, combine both
combined_df = pd.concat([
    menu_df_cleaned.assign(Collection='Menu'),
    expanded_df.assign(Collection='Music')
], ignore_index=True)

# Ensure Year is numeric for combined_df
combined_df['Year'] = pd.to_numeric(combined_df['Year'], errors='coerce')

# Check that Music rows have valid Year
print(combined_df[combined_df['Collection'] == 'Music'][['Year', 'Title']].head())

# Plot
plt.figure(figsize=(12, 6))
sns.histplot(
    data=combined_df,
    x="Year",
    hue="Collection",
    bins=30,
    kde=True,
    multiple="stack"
)
plt.title("Cultural Timeline: Music vs Menu Works Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()
# Out:
#         Year                               Title
# 2313  1902.0  Glühwürmchen-Idyll Aus "Lysistrata
# 2314  1908.0              Immer An Der Wand Lang
# 2315  1908.0                Der Letzte Frou-Frou
# 2316  1908.0            Der Zurückgekehrte Taler
# 2317  1908.0                           Donaunixe
